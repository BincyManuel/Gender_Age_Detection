# %% [markdown]
# Import necessary libraries

# %%
import cv2
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# %% [markdown]
# Initialize the MTCNN detector

# %%
detector = MTCNN()

# %%
def detect_faces(image_path):
    image = cv2.imread(image_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    faces = detector.detect_faces(image_rgb)

    for face in faces:
        x, y, width, height = face['box']
        cv2.rectangle(image, (x, y), (x + width, y + height), (255, 0, 0), 2)

    return image, faces

# %% [markdown]
# Testing Image 1

# %%
image_path = "C:/Users/DELL/null_class/gender_age/test8.jpg"
detected_image, detected_faces = detect_faces(image_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step

# %% [markdown]
# Display the image

# %%
plt.imshow(cv2.cvtColor(detected_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# Print the faces information

# %%
print(detected_faces)
# Out:
# [{'box': [21, 503, 164, 209], 'confidence': 0.9999998807907104, 'keypoints': {'left_eye': (96, 584), 'right_eye': (162, 604), 'nose': (131, 629), 'mouth_left': (82, 654), 'mouth_right': (140, 672)}}, {'box': [1554, 576, 149, 199], 'confidence': 0.9999963045120239, 'keypoints': {'left_eye': (1583, 660), 'right_eye': (1649, 662), 'nose': (1600, 688), 'mouth_left': (1580, 726), 'mouth_right': (1634, 731)}}, {'box': [433, 629, 97, 133], 'confidence': 0.9999442100524902, 'keypoints': {'left_eye': (468, 677), 'right_eye': (515, 682), 'nose': (497, 708), 'mouth_left': (469, 729), 'mouth_right': (509, 731)}}, {'box': [953, 469, 79, 105], 'confidence': 0.9999402761459351, 'keypoints': {'left_eye': (976, 513), 'right_eye': (1014, 514), 'nose': (995, 533), 'mouth_left': (974, 545), 'mouth_right': (1015, 544)}}, {'box': [1403, 618, 102, 128], 'confidence': 0.999466598033905, 'keypoints': {'left_eye': (1425, 668), 'right_eye': (1474, 666), 'nose': (1444, 689), 'mouth_left': (1428, 716), 'mouth_right': (1469, 715)}}]
